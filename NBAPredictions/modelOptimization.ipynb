# %%
#import dependencies
import pandas as pd
import tensorflow as tf
import os
import pandas as pd 
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, InputLayer, Dropout, BatchNormalization
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('NBAdata2007-2024.csv')
df
# Out:
#                  date                homeTeam homeTeam_id  \
# 0       June 17, 2024          Boston Celtics         BOS
# 1       June 14, 2024        Dallas Mavericks         DAL
# 2       June 12, 2024        Dallas Mavericks         DAL
# 3       June 09, 2024          Boston Celtics         BOS
# 4       June 06, 2024          Boston Celtics         BOS
# ...               ...                     ...         ...
# 21872  April 18, 2007        Sacramento Kings         SAC
# 21873  April 18, 2007  Portland Trail Blazers         POR
# 21874  April 18, 2007           Orlando Magic         ORL
# 21875  April 18, 2007         New Jersey Nets         NJN
# 21876  April 18, 2007  Minnesota Timberwolves         MIN
#
#        homeTeam_points_total  homeTeam_points_q1  homeTeam_points_q2  \
# 0                        106                  28                  39
# 1                        122                  34                  27
# ...

# %%
subjectID_dict = {
    "ATL": 1,
    "BOS": 2,
    "BKN": 3,
    "CHA": 4,
    "CHI": 5,
    "CLE": 6,
    "DAL": 7,
    "DEN": 8,
    "DET": 9,
    "GSW": 10,
    "HOU": 11,
    "IND": 12,
    "LAC": 13,
    "LAL": 14,
    "MEM": 15,
    "MIA": 16,
    "MIL": 17,
    "MIN": 18,
    "NOP": 19,
    "NYK": 20,
    "OKC": 21,
    "ORL": 22,
    "PHI": 23,
    "PHX": 24,
    "POR": 25,
    "SAC": 26,
    "SAS": 27,
    "TOR": 28,
    "UTA": 29,
    "WAS": 30,
    #These are mapping to franchise moves
    "NOH": 19, #New Orleans Hornets rebranded to Pelicans
    "NJN": 3, #New Jersey Nets relocated to Brooklyn - 2012
    "SEA": 21 #Seattle Supersonics relocated to OKC and rebranded to Thunder - 2008
}
